# %% [markdown]
# # Foucault Knife Edge Test
#
# **Scott Prahl**
#
# **April 2021**

# %%
import numpy as np
import matplotlib.pyplot as plt
import lenstest

# %%
D = 3*25.4
RoC = 160*25.4
offset = -9
x_offset = -0.05
conic = 0
phi = np.radians(90)

lenstest.foucault.foucault_plot(D, RoC, x_offset, offset, conic, phi=phi, A1=0.000002)
plt.show()
