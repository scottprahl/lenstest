# %% [markdown]
# # Foucault Knife Edge Test
#
# **Scott Prahl**
#
# **April 2021**

# %%
import numpy as np
import matplotlib.pyplot as plt
import lenstest

# %%
D = 20*25.4
RoC = 160*25.4
offset = 1
x_offset = -0.03
conic = 0
phi = np.radians(0)

lenstest.foucault.foucault_plot(D, RoC, x_offset, offset, conic, phi=phi)
plt.show()
